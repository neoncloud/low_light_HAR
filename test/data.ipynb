# %%
import os,sys
parent_dir = os.path.abspath('../')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
from data.dataset import VideoDataset

# %%
data = VideoDataset(total_frames=32, frame_size=224, video_label_path='/home/neoncloud/low_light_video/mapping_table.txt', video_list_path='/home/neoncloud/low_light_video/train_.txt')

# %%
frames, label = data[6]

# %%
import matplotlib.pyplot as plt
plt.imshow(frames[31])

# %%
print(label)
# Out:
# Drink
