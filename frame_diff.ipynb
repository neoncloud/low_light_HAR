# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from dark_enhance import DarkEnhance
from frame_diff import Sandevistan

# %%
from torchvision.io import read_video
frames, _, info  = read_video('./Run_1_1.mp4')
print('frames',frames.shape)
# Out:
# frames torch.Size([81, 240, 320, 3])

# %%
enhancer = DarkEnhance()
frame_diff = Sandevistan(n_frames=10,thres=200.0)
frames = enhancer(frames).transpose(3,1).unsqueeze(0)
out = frame_diff(frames.clone())

# %%
plt.pcolor(out.squeeze()[7].transpose(0,1).flip(0).numpy())
